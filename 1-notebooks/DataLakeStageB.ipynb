# %%
import logging


def init_logger(file_name, log_level=None):
    if not log_level:
        log_level = "INFO"
    logging.basicConfig()
    logger = logging.getLogger(file_name)
    logger.setLevel(getattr(logging, log_level))
    return logger

# %%
import awswrangler as wr
import boto3
import pandas as pd
from collections import defaultdict
import json
import numpy as np

# %%
logger = init_logger(__name__)

# %%
myProfile = 'jvalenzuela-tesis'
mySession = boto3.session.Session(profile_name=myProfile, region_name = 'us-east-1')
ssmClient = mySession.client('ssm', region_name = 'us-east-1')

# %%
rawBucket = ssmClient.get_parameter(Name='/Master/S3/CentralBucket')['Parameter']['Value']
stageBucket = ssmClient.get_parameter(Name='/Master/S3/StageBucket')['Parameter']['Value']
analyticsBucket = ssmClient.get_parameter(Name='/Master/S3/AnalyticsBucket')['Parameter']['Value']

# %%
event = {"dataset":"events"}
context = None

# %%
def lambda_handler(event, context): 
    try:
        dataset = event['dataset']
        analyticsDataset = f'an{dataset}'
        s3StagePath = f"s3://{stageBucket}/datalake/{dataset}/"
        s3AnalyticsPath = f"s3://{analyticsBucket}/datalake/{analyticsDataset}2/"
        
        print(f"Using tha following Stage bucket Path: {s3StagePath}")        
        transformDataframeEvents(s3StagePath, s3AnalyticsPath)
        
    except Exception as e: 
        print(f"Error on LambdaHandler has ocurred: {str(e)}")

# %%
def transformDataframeEvents(s3StagePath, s3AnalyticsPath):
    
    df = wr.s3.read_parquet(s3StagePath, dataset=True, boto3_session=mySession)
    
    df=df[(df['period']!=5)]
    df[['loc_x','loc_y']] = df.location.apply(pd.Series)
    df['loc_x']=df['loc_x'].replace("NaN", value=pd.np.nan).astype(float)
    df['loc_y']=df['loc_y'].replace("NaN", value=pd.np.nan).astype(float)
    df['loc_x'] = df['loc_x'].fillna(-1)
    df['loc_y'] = df['loc_y'].fillna(-1)
    
    #creacion de variables 
    df['shot.dangerous'] = np.where((df['loc_x'].astype(int)>=94) & (df['loc_y'].astype(int)>=25) & (df['loc_y'].astype(int)<=60), True, False)
    
    df_array = []
    #Agrupar por posession, quiero saber todas las maniobras en un shot. 
    for (cc), group_poss in df.groupby('possession'):

        if True in set(group_poss['shot.dangerous']):
          group_poss['possession.dangerous']= 'True'
          group_poss['possession']= cc
        else:
          group_poss['possession.dangerous']= 'False'
          group_poss['possession']= cc
        groupo=group_poss[(group_poss['possession.dangerous']=='True')]
        df_array.append(groupo)

    df_concat_events = pd.concat(df_array)
    
    print(f"Lenght of array : {len(df_array)}")
    
    wr.s3.to_parquet(
            df=df_concat_events,
            path= s3AnalyticsPath,
            dataset = True,
            mode = 'overwrite_partitions',
            partition_cols = ['match_id'],
            boto3_session=mySession
        )

# %%
lambda_handler(event, context)
# Out:
# Using tha following Stage bucket Path: s3://soccer-datalake-dev-us-east-1-829547505377-stage/datalake/events/
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# ...
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:7: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df['loc_x']=df['loc_x'].replace("NaN", value=pd.np.nan).astype(float)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/2034134403.py:8: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df['loc_y']=df['loc_y'].replace("NaN", value=pd.np.nan).astype(float)
# Lenght of array : 198
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/s3/_write_dataset.py:92: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for keys, subgroup in df.groupby(by=partition_cols, observed=True):

# %%
s3StagePath = f"s3://{stageBucket}/datalake/events/"
df = wr.s3.read_parquet(s3StagePath, dataset=True, boto3_session=mySession)
    
df=df[(df['period']!=5)]

# %%
df[['loc_x','loc_y']] = df.location.apply(pd.Series)
df['loc_x']=df['loc_x'].replace("NaN", value=pd.np.nan).astype(float)
df['loc_y']=df['loc_y'].replace("NaN", value=pd.np.nan).astype(float)
df['loc_x'] = df['loc_x'].fillna(-1)
df['loc_y'] = df['loc_y'].fillna(-1)
#creacion de variables 
df['shot.dangerous'] = np.where((df['loc_x'].astype(int)>=94) & (df['loc_y'].astype(int)>=25) & (df['loc_y'].astype(int)<=60), True, False)
# Out:
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# ...
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df[['loc_x','loc_y']] = df.location.apply(pd.Series)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df['loc_x']=df['loc_x'].replace("NaN", value=pd.np.nan).astype(float)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/42238408.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df['loc_y']=df['loc_y'].replace("NaN", value=pd.np.nan).astype(float)

# %%
df_array = []
#Agrupar por posession, quiero saber todas las maniobras en un shot. 
for (cc), group_poss in df.groupby('possession'):

    if True in set(group_poss['shot.dangerous']):
      group_poss['possession.dangerous']= 'True'
      group_poss['possession']= cc
    else:
      group_poss['possession.dangerous']= 'False'
      group_poss['possession']= cc
    groupo=group_poss[(group_poss['possession.dangerous']=='True')]
    df_array.append(groupo)

df_concat_events = pd.concat(df_array)

# %%
s3AnalyticsPath = f"s3://{analyticsBucket}/datalake/anevents/"

# %%
print(f"Lenght of array : {len(df_array)}")

wr.s3.to_parquet(
        df=df_concat_events,
        path= s3AnalyticsPath,
        dataset = True,
        mode = 'overwrite_partitions',
        partition_cols = ['match_id'],
        boto3_session=mySession
    )
# Out:
# Lenght of array : 294
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/s3/_write_dataset.py:92: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for keys, subgroup in df.groupby(by=partition_cols, observed=True):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/f4/xgxbfgyd78l0z48nck9l57zh0000gn/T/ipykernel_39717/1824739173.py in <module>
#       1 print(f"Lenght of array : {len(df_array)}")
#       2
# ----> 3 wr.s3.to_parquet(
#       4         df=df_concat_events,
#       5         path= s3AnalyticsPath,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/_config.py in wrapper(*args_raw, **kwargs)
#     494                 del args[name]
#     495                 args = {**args, **keywords}
# --> 496         return function(**args)
#     497
#     498     wrapper.__doc__ = _inject_config_doc(doc=function.__doc__, available_configs=available_configs)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/s3/_write_parquet.py in to_parquet(df, path, index, compression, pyarrow_additional_kwargs, max_rows_by_file, use_threads, boto3_session, s3_additional_kwargs, sanitize_columns, dataset, filename_prefix, partition_cols, bucketing_info, concurrent_partitioning, mode, catalog_versioning, schema_evolution, database, table, table_type, transaction_id, dtype, description, parameters, columns_comments, regular_partitions, projection_enabled, projection_types, projection_ranges, projection_values, projection_intervals, projection_digits, projection_formats, projection_storage_location_template, catalog_id)
#     650                 )
#     651
# --> 652         paths, partitions_values = _to_dataset(
#     653             func=_to_parquet,
#     654             concurrent_partitioning=concurrent_partitioning,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/s3/_write_dataset.py in _to_dataset(func, concurrent_partitioning, df, path_root, filename_prefix, index, use_threads, mode, partition_cols, partitions_types, catalog_id, database, table, table_type, transaction_id, bucketing_info, boto3_session, **func_kwargs)
#     233     paths: List[str]
#     234     if partition_cols:
# --> 235         paths, partitions_values = _to_partitions(
#     236             func=func,
#     237             concurrent_partitioning=concurrent_partitioning,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/s3/_write_dataset.py in _to_partitions(func, concurrent_partitioning, df, path_root, use_threads, mode, partition_cols, partitions_types, catalog_id, database, table, table_type, transaction_id, bucketing_info, filename_prefix, boto3_session, **func_kwargs)
#     138             )
#     139         else:
# --> 140             proxy.write(
#     141                 func=func,
#     142                 df=subgroup,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/s3/_write_concurrent.py in write(self, func, boto3_session, **func_kwargs)
#      46             self._futures.append(future)
#      47         else:
# ---> 48             self._results += func(boto3_session=boto3_session, **func_kwargs)
#      49
#      50     def close(self) -> List[str]:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/s3/_write_parquet.py in _to_parquet(df, schema, index, compression, compression_ext, pyarrow_additional_kwargs, cpus, dtype, boto3_session, s3_additional_kwargs, use_threads, path, path_root, filename_prefix, max_rows_by_file)
#     189             use_threads=use_threads,
#     190         ) as writer:
# --> 191             writer.write_table(table)
#     192         paths = [file_path]
#     193     return paths
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py in __exit__(self, type, value, traceback)
#     122         if type is None:
#     123             try:
# --> 124                 next(self.gen)
#     125             except StopIteration:
#     126                 return False
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/s3/_write_parquet.py in _new_writer(file_path, compression, pyarrow_additional_kwargs, schema, boto3_session, s3_additional_kwargs, use_threads)
#      76         finally:
#      77             if writer is not None and writer.is_open is True:
# ---> 78                 writer.close()
#      79
#      80
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py in __exit__(self, type, value, traceback)
#     122         if type is None:
#     123             try:
# --> 124                 next(self.gen)
#     125             except StopIteration:
#     126                 return False
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/s3/_fs.py in open_s3_object(path, mode, version_id, use_threads, s3_additional_kwargs, s3_block_size, boto3_session, newline, encoding)
#     586             text_s3obj.close()
#     587         if s3obj is not None and s3obj.closed is False:
# --> 588             s3obj.close()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/s3/_fs.py in close(self)
#     472             elif self._buffer.tell() > 0:
#     473                 _logger.debug("put_object")
# --> 474                 _utils.try_it(
#     475                     f=self._client.put_object,
#     476                     ex=_S3_RETRYABLE_ERRORS,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/_utils.py in try_it(f, ex, ex_code, base, max_num_tries, **kwargs)
#     346     for i in range(max_num_tries):
#     347         try:
# --> 348             return f(**kwargs)
#     349         except ex as exception:
#     350             if ex_code is not None and hasattr(exception, "response"):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     528                 )
#     529             # The "self" in this scope is referring to the BaseClient.
# --> 530             return self._make_api_call(operation_name, kwargs)
#     531
#     532         _api_call.__name__ = str(py_operation_name)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     941         else:
#     942             apply_request_checksum(request_dict)
# --> 943             http, parsed_response = self._make_request(
#     944                 operation_model, request_dict, request_context
#     945             )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     964     def _make_request(self, operation_model, request_dict, request_context):
#     965         try:
# --> 966             return self._endpoint.make_request(operation_model, request_dict)
#     967         except Exception as e:
#     968             self.meta.events.emit(
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     117             request_dict,
#     118         )
# --> 119         return self._send_request(request_dict, operation_model)
#     120
#     121     def create_request(self, params, operation_model=None):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     197         self._update_retries_context(context, attempts)
#     198         request = self.create_request(request_dict, operation_model)
# --> 199         success_response, exception = self._get_response(
#     200             request, operation_model, context
#     201         )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/endpoint.py in _get_response(self, request, operation_model, context)
#     239         # If an exception occurs then the success_response is None.
#     240         # If no exception occurs then exception is None.
# --> 241         success_response, exception = self._do_get_response(
#     242             request, operation_model, context
#     243         )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/endpoint.py in _do_get_response(self, request, operation_model, context)
#     279             http_response = first_non_none_response(responses)
#     280             if http_response is None:
# --> 281                 http_response = self._send(request)
#     282         except HTTPClientError as e:
#     283             return (None, e)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/endpoint.py in _send(self, request)
#     375
#     376     def _send(self, request):
# --> 377         return self.http_session.send(request)
#     378
#     379
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/httpsession.py in send(self, request)
#     453
#     454             request_target = self._get_request_target(request.url, proxy_url)
# --> 455             urllib_response = conn.urlopen(
#     456                 method=request.method,
#     457                 url=request_target,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     392                 conn.request_chunked(method, url, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#     396         # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connection.py in request(self, method, url, body, headers)
#     232         if "user-agent" not in (six.ensure_str(k.lower()) for k in headers):
#     233             headers["User-Agent"] = _get_default_user_agent()
# --> 234         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     235
#     236     def request_chunked(self, method, url, body=None, headers=None):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1251                 encode_chunked=False):
#    1252         """Send a complete request to the server."""
# -> 1253         self._send_request(method, url, body, headers, encode_chunked)
#    1254
#    1255     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/awsrequest.py in _send_request(self, method, url, body, headers, *args, **kwargs)
#      92             self._expect_header_set = False
#      93             self.response_class = self._original_response_cls
# ---> 94         rval = super()._send_request(
#      95             method, url, body, headers, *args, **kwargs
#      96         )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             # default charset of iso-8859-1.
#    1298             body = _encode(body, 'body')
# -> 1299         self.endheaders(body, encode_chunked=encode_chunked)
#    1300
#    1301     def getresponse(self):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in endheaders(self, message_body, encode_chunked)
#    1246         else:
#    1247             raise CannotSendHeader()
# -> 1248         self._send_output(message_body, encode_chunked=encode_chunked)
#    1249
#    1250     def request(self, method, url, body=None, headers={}, *,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/awsrequest.py in _send_output(self, message_body, *args, **kwargs)
#     128             # Wait for 1 second for the server to send a response.
#     129             if urllib3.util.wait_for_read(self.sock, 1):
# --> 130                 self._handle_expect_response(message_body)
#     131                 return
#     132             else:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/awsrequest.py in _handle_expect_response(self, message_body)
#     174                     "100 Continue response seen, now sending request body."
#     175                 )
# --> 176                 self._send_message_body(message_body)
#     177             elif len(parts) == 3 and parts[0].startswith(b'HTTP/'):
#     178                 # From the RFC:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/awsrequest.py in _send_message_body(self, message_body)
#     207     def _send_message_body(self, message_body):
#     208         if message_body is not None:
# --> 209             self.send(message_body)
#     210
#     211     def send(self, str):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/botocore/awsrequest.py in send(self, str)
#     216             )
#     217             return
# --> 218         return super().send(str)
#     219
#     220     def _is_100_continue_status(self, maybe_status_line):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in send(self, data)
#     964                 if encode:
#     965                     datablock = datablock.encode("iso-8859-1")
# --> 966                 self.sock.sendall(datablock)
#     967             return
#     968         try:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py in sendall(self, data, flags)
#    1202                 amount = len(byte_view)
#    1203                 while count < amount:
# -> 1204                     v = self.send(byte_view[count:])
#    1205                     count += v
#    1206         else:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py in send(self, data, flags)
#    1171                     "non-zero flags not allowed in calls to send() on %s" %
#    1172                     self.__class__)
# -> 1173             return self._sslobj.write(data)
#    1174         else:
#    1175             return super().send(data, flags)
#
# KeyboardInterrupt:

# %%
s3StagePath = f"s3://{stageBucket}/datalake/events/"

# %%
df = wr.s3.read_parquet(s3StagePath, dataset=True, boto3_session=mySession)

# %%
df=df[(df['period']!=5)]

# %%
#df[['loc_x','loc_y']]=df["location"].apply(lambda x: pd.Series(str(x).strip('[]').split(",")))
df[['loc_x','loc_y']] = df.location.apply(pd.Series)
df['loc_x']=df['loc_x'].replace("NaN", value=pd.np.nan).astype(float)
df['loc_y']=df['loc_y'].replace("NaN", value=pd.np.nan).astype(float)
df['loc_x'] = df['loc_x'].fillna(-1)
df['loc_y'] = df['loc_y'].fillna(-1)

# %%
import numpy as np

# %%
#creacion de variables 
df['shot.dangerous'] = np.where((df['loc_x'].astype(int)>=94) & (df['loc_y'].astype(int)>=25) & (df['loc_y'].astype(int)<=60), True, False)

# %%
df_array = []
#Agrupar por posession, quiero saber todas las maniobras en un shot. 
for (cc), group_poss in df.groupby('possession'):

    if True in set(group_poss['shot.dangerous']):
      group_poss['possession.dangerous']= 'True'
      group_poss['possession']= cc
    else:
      group_poss['possession.dangerous']= 'False'
      group_poss['possession']= cc
    groupo=group_poss[(group_poss['possession.dangerous']=='True')]
    df_array.append(groupo)
    
df_concat_events = pd.concat(df_array)

# %%
s3AnalyticsPath = f"s3://{analyticsBucket}/datalake/anevents/"

# %%
wr.s3.to_parquet(
            df=df_concat_events,
            path= s3AnalyticsPath,
            dataset = True,
            mode = 'overwrite_partitions',
            partition_cols = ['filename'],
            boto3_session=mySession
        )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/awswrangler/s3/_write_dataset.py:92: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for keys, subgroup in df.groupby(by=partition_cols, observed=True):
# {'paths': ['s3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=15946/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=15956/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=15973/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=15978/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=15986/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=15998/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16010/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16023/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16029/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16056/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16073/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16079/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16086/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16095/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16109/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16120/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16131/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16136/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16149/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16157/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16173/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16182/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16190/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16196/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16205/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16215/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16231/186d9671175c4259a4bfcc786c852843.snappy.parquet',
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16240/186d9671175c4259a4bfcc786c852843.snappy.parquet'],
#  'partitions_values': {'s3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=15946/': ['15946'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=15956/': ['15956'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=15973/': ['15973'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=15978/': ['15978'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=15986/': ['15986'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=15998/': ['15998'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16010/': ['16010'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16023/': ['16023'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16029/': ['16029'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16056/': ['16056'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16073/': ['16073'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16079/': ['16079'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16086/': ['16086'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16095/': ['16095'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16109/': ['16109'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16120/': ['16120'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16131/': ['16131'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16136/': ['16136'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16149/': ['16149'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16157/': ['16157'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16173/': ['16173'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16182/': ['16182'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16190/': ['16190'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16196/': ['16196'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16205/': ['16205'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16215/': ['16215'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16231/': ['16231'],
#   's3://soccer-datalake-dev-us-east-1-829547505377-analytics/datalake/anevents/filename=16240/': ['16240']}}

# %%
df_array = []
for f_name in glob(eventsFiles + '\*.json'):
  f = open (f_name, "r", encoding="utf8")
  df = pd.json_normalize(json.loads(f.read()) 
              #record_path =['lineup'] 
              #meta=['team_id', 'team_name']
            )
  file_name = os.path.splitext(os.path.basename(f_name))[0]
  df['match_id']=file_name
  print(file_name)
  
  #Penales parte final
  df=df[(df['period']!=5)]
  
  df[['loc_x','loc_y']]=df["location"].apply(lambda x: pd.Series(str(x).strip('[]').split(",")))
  df['loc_x']=df['loc_x'].replace("NaN", value=pd.np.nan).astype(float)
  df['loc_y']=df['loc_y'].replace("NaN", value=pd.np.nan).astype(float)
  df['loc_x'] = df['loc_x'].fillna(-1)
  df['loc_y'] = df['loc_y'].fillna(-1)

  #creacion de variables 
  df['shot.dangerous'] = np.where((df['loc_x'].astype(int)>=94) & (df['loc_y'].astype(int)>=25) & (df['loc_y'].astype(int)<=60), True, False)
  
  #Agrupar por posession, quiero saber todas las maniobras en un shot. 
  for (cc), group_poss in df.groupby('possession'):

    if True in set(group_poss['shot.dangerous']):
      group_poss['possession.dangerous']= 'True'
      group_poss['possession']= cc
    else:
      group_poss['possession.dangerous']= 'False'
      group_poss['possession']= cc
    groupo=group_poss[(group_poss['possession.dangerous']=='True')]
    df_array.append(groupo)
    
df_concat_events = pd.concat(df_array)
print('Done')
